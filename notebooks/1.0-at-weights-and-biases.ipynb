# %% [markdown]
# # 1. Getting Started
# ## a) Connection à Weights and Biases

# %%
# 1. Log in to your W&B account
import wandb

wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /home/user/.netrc
# wandb: Currently logged in as: sebastien-s to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# ## Import Data
#
# As described in the `DVC` course, you need to download the data first.
#
# In other to run the script for this notebook, we need to adjust a bit the ingestion script.
#
# Below you will find the update that you need to perform. You simply need to change `raw_data_relative_path="./data/raw"` to `raw_data_relative_path="../data/raw"` in the `main` function of the `src/data/import_raw_data.py` script.
#
# ```py
# def main(raw_data_relative_path="../data/raw", # just add .. before data/raw
#         ## The rest of the code..`
# ```

# %%
# import data
# !echo y | python ../src/data/import_raw_data.py
# Out:
# raw doesn't exists. Do you want to create it? (y/n): downloading https://mlops-project-db.s3.eu-west-1.amazonaws.com/accidents/caracteristiques-2021.csv as caracteristiques-2021.csv
# downloading https://mlops-project-db.s3.eu-west-1.amazonaws.com/accidents/lieux-2021.csv as lieux-2021.csv
# downloading https://mlops-project-db.s3.eu-west-1.amazonaws.com/accidents/usagers-2021.csv as usagers-2021.csv
# downloading https://mlops-project-db.s3.eu-west-1.amazonaws.com/accidents/vehicules-2021.csv as vehicules-2021.csv
# 2025-02-19 12:42:02,269 - __main__ - INFO - making raw data set

# %% [markdown]
# Now let's adjust the the `make_dataset.py` script as well to make it work inside this jupyter notebook.
#
# Before executing the command below, change all the `\\` to `/` in the `main` function.
#
# ```py
# def main(input_filepath, output_filepath):
#     # same code
#
#     # Prompt the user for input file paths
#     input_filepath= click.prompt('Enter the file path for the input data', type=click.Path(exists=True))
#     input_filepath_users = f"{input_filepath}/usagers-2021.csv" # change `\\` to `/`
#     input_filepath_caract = f"{input_filepath}/caracteristiques-2021.csv" # change `\\` to `/`
#     input_filepath_places = f"{input_filepath}/lieux-2021.csv" # change `\\` to `/`
#     input_filepath_veh = f"{input_filepath}`vehicules-2021.csv" # change `\\` to `/`
#     output_filepath = click.prompt('Enter the file path for the output preprocessed data (e.g., output/preprocessed_data.csv)', type=click.Path())
#
#     # same code
# ```

# %%
# preprocess data
# !printf "../data/raw\n../data/preprocessed\ny\n" | python ../src/data/make_dataset.py
# Out:
# 2025-02-19 12:50:16,955 - __main__ - INFO - making final data set from raw data
# Enter the file path for the input data: Enter the file path for the output preprocessed data (e.g., output/preprocessed_data.csv): /home/user/FIES/Template_MLOps_accidents/notebooks/../src/data/make_dataset.py:55: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_users.grav.replace([1,2,3,4], [1,3,4,2], inplace = True)
# /home/user/FIES/Template_MLOps_accidents/notebooks/../src/data/make_dataset.py:77: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_veh['catv'].replace(catv_value, catv_value_new, inplace = True)
# /home/user/FIES/Template_MLOps_accidents/notebooks/../src/data/make_dataset.py:93: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['grav'].replace([2,3,4], [0,1,1], inplace=True)
# preprocessed doesn't exists. Do you want to create it? (y/n):

# %% [markdown]
# ## b) Première run W&B

# %%
# 2. Start a W&B Run
run = wandb.init(
    project="classification-car-accidents",
    name='My first run',
    tags=["baseline", "random-forest"],
)
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/home/user/FIES/Template_MLOps_accidents/notebooks/wandb/run-20250219_124211-7sf5my6t</code>
# Syncing run <strong><a href='https://wandb.ai/sebastien-s/classification-car-accidents/runs/7sf5my6t' target="_blank">My first run</a></strong> to <a href='https://wandb.ai/sebastien-s/classification-car-accidents' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sebastien-s/classification-car-accidents' target="_blank">https://wandb.ai/sebastien-s/classification-car-accidents</a>
#  View run at <a href='https://wandb.ai/sebastien-s/classification-car-accidents/runs/7sf5my6t' target="_blank">https://wandb.ai/sebastien-s/classification-car-accidents/runs/7sf5my6t</a>

# %%
#  3. Capture a dictionary of hyperparameters
params = {"n_estimators": 2, "criterion": 'gini', "max_depth": 2}

wandb.config = params

# %%
# 4. Train the model
import pandas as pd 
from sklearn.ensemble import RandomForestClassifier
import numpy as np

X_train = pd.read_csv('../data/preprocessed/X_train.csv')
X_test = pd.read_csv('../data/preprocessed/X_test.csv')
y_train = pd.read_csv('../data/preprocessed/y_train.csv')
y_test = pd.read_csv('../data/preprocessed/y_test.csv')
y_train = np.ravel(y_train)
y_test = np.ravel(y_test)

rf_classifier = RandomForestClassifier(**params)

rf_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=2, n_estimators=2)

# %%
# 5. Capture a dictionary of metrics
train_accuracy = rf_classifier.score(X_train, y_train)
test_accuracy = rf_classifier.score(X_test, y_test)
wandb.log({"train_accuracy": train_accuracy, "test_accuracy": test_accuracy})

# %%
# 6. Track model artifact
import joblib

#Save the trained model to a file
model_filename = '../models/trained_model.joblib'
joblib.dump(rf_classifier, model_filename)

#Track the file
wandb.log_artifact(model_filename)
# Out:
# <Artifact run-7sf5my6t-trained_model.joblib>

# %%
# 7. Finish the run
wandb.finish()
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>train_accuracy</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_accuracy</td><td>0.70238</td></tr><tr><td>train_accuracy</td><td>0.70247</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">My first run</strong> at: <a href='https://wandb.ai/sebastien-s/classification-car-accidents/runs/7sf5my6t' target="_blank">https://wandb.ai/sebastien-s/classification-car-accidents/runs/7sf5my6t</a><br> View project at: <a href='https://wandb.ai/sebastien-s/classification-car-accidents' target="_blank">https://wandb.ai/sebastien-s/classification-car-accidents</a><br>Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250219_124211-7sf5my6t/logs</code>

# %% [markdown]
# # 2. Visualisation des métriques
#
# ## c) Seconde Run W&B

# %%
# 1. Log in to your W&B account
wandb.login()

# 2. Start a W&B Run
run = wandb.init(
    project="classification-car-accidents",
    name='My second run',
    tags=["baseline", "Decision Tree"],
)

#  3. Capture a dictionary of hyperparameters
params = {"criterion": 'gini', "max_depth": 10}

wandb.config = params

# 4. Train the model
from sklearn.tree import DecisionTreeClassifier

dt_classifier = DecisionTreeClassifier(**params)
dt_classifier.fit(X_train, y_train)
# Out:
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/home/user/FIES/Template_MLOps_accidents/notebooks/wandb/run-20250219_125442-18il73dh</code>
# Syncing run <strong><a href='https://wandb.ai/sebastien-s/classification-car-accidents/runs/18il73dh' target="_blank">My second run</a></strong> to <a href='https://wandb.ai/sebastien-s/classification-car-accidents' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sebastien-s/classification-car-accidents' target="_blank">https://wandb.ai/sebastien-s/classification-car-accidents</a>
#  View run at <a href='https://wandb.ai/sebastien-s/classification-car-accidents/runs/18il73dh' target="_blank">https://wandb.ai/sebastien-s/classification-car-accidents/runs/18il73dh</a>
# DecisionTreeClassifier(max_depth=10)

# %%
# 5. Capture a dictionary of metrics 
train_accuracy = dt_classifier.score(X_train, y_train)
test_accuracy = dt_classifier.score(X_test, y_test)
wandb.log({"train_accuracy": train_accuracy, "test_accuracy": test_accuracy})

# %%
# 6. Track plots and log artifacts with sklearn.plot_classifier
y_pred = dt_classifier.predict(X_test)
y_probas = dt_classifier.predict_proba(X_test)
labels = ['non-prioritary accident', 'prioritary accident']

wandb.sklearn.plot_classifier(
    dt_classifier,
    X_train,
    X_test,
    y_train,
    y_test,
    y_pred,
    y_probas,
    labels,
    model_name="Decision Tree",
    feature_names=X_train.columns,
)

# 7. Finish the run
wandb.finish()
# Out:
# wandb:
# wandb: Plotting Decision Tree.
# /home/user/FIES/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# wandb: Logged feature importances.
# wandb: Logged confusion matrix.
# /home/user/FIES/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# wandb: Logged summary metrics.
# wandb: Logged class proportions.
# /home/user/FIES/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# /home/user/FIES/.venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# wandb: Logged calibration curve.
# wandb: Logged roc curve.
# wandb: Logged precision-recall curve.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>train_accuracy</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_accuracy</td><td>0.75198</td></tr><tr><td>train_accuracy</td><td>0.80096</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">My second run</strong> at: <a href='https://wandb.ai/sebastien-s/classification-car-accidents/runs/18il73dh' target="_blank">https://wandb.ai/sebastien-s/classification-car-accidents/runs/18il73dh</a><br> View project at: <a href='https://wandb.ai/sebastien-s/classification-car-accidents' target="_blank">https://wandb.ai/sebastien-s/classification-car-accidents</a><br>Synced 5 W&B file(s), 7 media file(s), 14 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250219_125442-18il73dh/logs</code>

# %% [markdown]
# ## b) Comparer les runs entre elles

# %%
# 1. Log in to your W&B account
wandb.login()

# 2. Start a W&B Run
run = wandb.init(
    project="classification-car-accidents",
    name='My third run',
    tags=["baseline", "Decision Tree"],
)

#  3. Capture a dictionary of hyperparameters
params = {"criterion": 'entropy', "max_depth": 20}

wandb.config = params

# 4. Train the model
from sklearn.tree import DecisionTreeClassifier

dt_classifier = DecisionTreeClassifier(**params)
dt_classifier.fit(X_train, y_train)

# 5. Capture a dictionary of metrics 
train_accuracy = dt_classifier.score(X_train, y_train)
test_accuracy = dt_classifier.score(X_test, y_test)
wandb.log({"train_accuracy": train_accuracy, "test_accuracy": test_accuracy})

# 6. Track plots and log artifacts with sklearn.plot_classifier
y_pred = dt_classifier.predict(X_test)
y_probas = dt_classifier.predict_proba(X_test)
labels = ['non-prioritary accident', 'prioritary accident']

wandb.sklearn.plot_classifier(
    dt_classifier,
    X_train,
    X_test,
    y_train,
    y_test,
    y_pred,
    y_probas,
    labels,
    model_name="Decision Tree",
    feature_names=X_train.columns,
)

# 7. Finish the run
wandb.finish()

# %% [markdown]
# # 3. Sweeps
# ## b) Méthodes et hyperparamètres

# %%
# 1. Pick a method
sweep_config = {
    'method': 'random'
    }

# %%
# 2. Name hyperparameters
parameters_dict = {
    'criterion': {
        'values': ['gini', 'entropy', 'log_loss']
        },
    'splitter': {
        'values': ['best', 'random']
        },
    'max_depth': {
          'values': [None, 10, 20, 50, 100, 200, 500]
        },
    'random_state': {
        'values': [42]
    }
    }

sweep_config['parameters'] = parameters_dict

# %% [markdown]
# ## c) Lancement du Sweep

# %%
from sklearn.tree import DecisionTreeClassifier

# 3. Initialize the sweep
sweep_id = wandb.sweep(sweep_config, project="classification-car-accidents")

# 4. Define the training function
def train(parameters=None):
    run = wandb.init(
        project="classification-car-accidents",
        tags=["sweep", "Decision Tree"],
        config=parameters
    )

    parameters = wandb.config
    
    dt_classifier = DecisionTreeClassifier(**parameters)
    dt_classifier.fit(X_train, y_train)

    train_accuracy = dt_classifier.score(X_train, y_train)
    test_accuracy = dt_classifier.score(X_test, y_test)
    wandb.log({"train_accuracy": train_accuracy, "test_accuracy": test_accuracy})

    wandb.finish()

# 5. Run the sweep agent
wandb.agent(sweep_id, train, count=5)
